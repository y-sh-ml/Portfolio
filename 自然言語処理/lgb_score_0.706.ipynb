# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/riiid-test-answer-prediction/example_sample_submission.csv
# /kaggle/input/riiid-test-answer-prediction/example_test.csv
# /kaggle/input/riiid-test-answer-prediction/questions.csv
# /kaggle/input/riiid-test-answer-prediction/train.csv
# /kaggle/input/riiid-test-answer-prediction/lectures.csv
# /kaggle/input/riiid-test-answer-prediction/riiideducation/competition.cpython-37m-x86_64-linux-gnu.so
# /kaggle/input/riiid-test-answer-prediction/riiideducation/__init__.py

# %%
from sklearn.model_selection import train_test_split
import optuna
import lightgbm as lgb
from sklearn.metrics import roc_auc_score

# %%
import riiideducation
env = riiideducation.make_env()
iter_test = env.iter_test()

# %% [markdown]
# # Data

# %%
used_data_types_dict = {
    'timestamp': 'int64',
    'user_id': 'int32',
    'content_id': 'int16',
    'answered_correctly': 'int8',
    'prior_question_elapsed_time': 'float16',
    'prior_question_had_explanation': 'boolean'
}

train_df = pd.read_csv('/kaggle/input/riiid-test-answer-prediction/train.csv',
                       usecols = used_data_types_dict.keys(),
                       dtype=used_data_types_dict,
                       index_col = 0,
                       nrows=10**6)

print(train_df.dtypes)
print(train_df.shape)
train_df.head()
# Out:
# user_id                             int32
# content_id                          int16
# answered_correctly                   int8
# prior_question_elapsed_time       float16
# prior_question_had_explanation    boolean
# dtype: object
# (1000000, 5)
#            user_id  content_id  answered_correctly  \
# timestamp
# 0              115        5692                   1
# 56943          115        5716                   1
# 118363         115         128                   1
# 131167         115        7860                   1
# 137965         115        7922                   1
#
#            prior_question_elapsed_time  prior_question_had_explanation
# timestamp
# 0                                  NaN                            <NA>
# 56943                          36992.0                           False
# 118363                         55008.0                           False
# 131167                         19008.0                           False
# 137965                         11000.0                           False

# %%
test_df = pd.read_csv("/kaggle/input/riiid-test-answer-prediction/example_test.csv")

print(test_df.shape)
test_df.head()
# Out:
# (104, 11)
#    row_id  group_num    timestamp     user_id  content_id  content_type_id  \
# 0       0          0            0   275030867        5729                0
# 1       1          0  13309898705   554169193       12010                0
# 2       2          0   4213672059  1720860329         457                0
# 3       3          0  62798072960   288641214       13262                0
# 4       4          0  10585422061  1728340777        6119                0
#
#    task_container_id  prior_question_elapsed_time  \
# 0                  0                          NaN
# 1               4427                      19000.0
# 2                240                      17000.0
# 3                266                      23000.0
# 4                162                      72400.0
#
#   prior_question_had_explanation prior_group_answers_correct  \
# 0                            NaN                          []
# 1                           True                         NaN
# 2                           True                         NaN
# 3                           True                         NaN
# 4                           True                         NaN
#
#   prior_group_responses
# 0                    []
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
submission_df = pd.read_csv("/kaggle/input/riiid-test-answer-prediction/example_sample_submission.csv")

print(submission_df.shape)
submission_df.head()
# Out:
# (104, 3)
#    row_id  answered_correctly  group_num
# 0       0                 0.5          0
# 1       1                 0.5          0
# 2       2                 0.5          0
# 3       3                 0.5          0
# 4       4                 0.5          0

# %% [markdown]
# # Feature Engineering

# %%
features_df = train_df.iloc[:int(9/10 * len(train_df))]
train_df = train_df.iloc[int(9/10 * len(train_df)):]

# %%
print(features_df.dtypes)
print(features_df.shape)
features_df.head()
# Out:
# user_id                             int32
# content_id                          int16
# answered_correctly                   int8
# prior_question_elapsed_time       float16
# prior_question_had_explanation    boolean
# dtype: object
# (900000, 5)
#            user_id  content_id  answered_correctly  \
# timestamp
# 0              115        5692                   1
# 56943          115        5716                   1
# 118363         115         128                   1
# 131167         115        7860                   1
# 137965         115        7922                   1
#
#            prior_question_elapsed_time  prior_question_had_explanation
# timestamp
# 0                                  NaN                            <NA>
# 56943                          36992.0                           False
# 118363                         55008.0                           False
# 131167                         19008.0                           False
# 137965                         11000.0                           False

# %%
print(train_df.dtypes)
print(train_df.shape)
train_df.head()
# Out:
# user_id                             int32
# content_id                          int16
# answered_correctly                   int8
# prior_question_elapsed_time       float16
# prior_question_had_explanation    boolean
# dtype: object
# (100000, 5)
#               user_id  content_id  answered_correctly  \
# timestamp
# 23452298654  18789336        8144                   0
# 23452298654  18789336        8146                   0
# 23452320119  18789336       10166                   0
# 23452320119  18789336       10165                   0
# 23452320119  18789336       10167                   1
#
#              prior_question_elapsed_time  prior_question_had_explanation
# timestamp
# 23452298654                       4248.0                            True
# 23452298654                       4248.0                            True
# 23452320119                       2000.0                            True
# 23452320119                       2000.0                            True
# 23452320119                       2000.0                            True

# %%
train_questions_only_df = features_df[features_df['answered_correctly']!=-1]

grouped_by_user_df = train_questions_only_df.groupby('user_id')

user_answers_df = grouped_by_user_df.agg({'answered_correctly': ['mean', 'count','std','median','skew']}).copy()

user_answers_df.columns = ['mean_user_accuracy', 
                           'questions_answered', 
                           'std_user_accuracy', 
                           'median_user_accuracy', 
                           'skew_user_accuracy']

print(user_answers_df.dtypes)
print(user_answers_df.shape)
user_answers_df.head()
# Out:
# mean_user_accuracy      float64
# questions_answered        int64
# std_user_accuracy       float64
# median_user_accuracy    float64
# skew_user_accuracy      float64
# dtype: object
# (3458, 5)
#          mean_user_accuracy  questions_answered  std_user_accuracy  \
# user_id
# 115                0.695652                  46           0.465215
# 124                0.233333                  30           0.430183
# 2746               0.578947                  19           0.507257
# 5382               0.672000                 125           0.471374
# 8623               0.642202                 109           0.481566
#
#          median_user_accuracy  skew_user_accuracy
# user_id
# 115                       1.0           -0.879359
# 124                       0.0            1.328338
# 2746                      1.0           -0.347892
# 5382                      1.0           -0.741648
# 8623                      1.0           -0.601619

# %%
grouped_by_content_df = train_questions_only_df.groupby('content_id')

content_answers_df = grouped_by_content_df.agg({'answered_correctly': ['mean', 'count','std','median','skew']}).copy()

content_answers_df.columns = ['mean_accuracy', 
                              'question_asked', 
                              'std_accuracy', 
                              'median_accuracy', 
                              'skew_accuracy']

print(content_answers_df.dtypes)
print(content_answers_df.shape)
content_answers_df.head()
# Out:
# mean_accuracy      float64
# question_asked       int64
# std_accuracy       float64
# median_accuracy    float64
# skew_accuracy      float64
# dtype: object
# (12986, 5)
#             mean_accuracy  question_asked  std_accuracy  median_accuracy  \
# content_id
# 0                0.857143              70      0.352454              1.0
# 1                0.918367              49      0.276642              1.0
# 2                0.555276             398      0.497561              1.0
# 3                0.784091             176      0.412625              1.0
# 4                0.600760             263      0.490676              1.0
#
#             skew_accuracy
# content_id
# 0               -2.086215
# 1               -3.153323
# 2               -0.223312
# 3               -1.392819
# 4               -0.413848

# %%
del features_df
del grouped_by_user_df
del grouped_by_content_df

# %%
features = [
    'mean_user_accuracy', 
    'questions_answered',
    'std_user_accuracy', 
    'median_user_accuracy',
    'skew_user_accuracy',
    'mean_accuracy', 
    'question_asked',
    'std_accuracy', 
    'median_accuracy',
    'prior_question_elapsed_time', 
    'prior_question_had_explanation',
    'skew_accuracy'
]

target = 'answered_correctly'

# %%
train_df = train_df[train_df[target] != -1]

print(train_df.dtypes)
print(train_df.shape)
train_df.head()
# Out:
# user_id                             int32
# content_id                          int16
# answered_correctly                   int8
# prior_question_elapsed_time       float16
# prior_question_had_explanation    boolean
# dtype: object
# (97953, 5)
#               user_id  content_id  answered_correctly  \
# timestamp
# 23452298654  18789336        8144                   0
# 23452298654  18789336        8146                   0
# 23452320119  18789336       10166                   0
# 23452320119  18789336       10165                   0
# 23452320119  18789336       10167                   1
#
#              prior_question_elapsed_time  prior_question_had_explanation
# timestamp
# 23452298654                       4248.0                            True
# 23452298654                       4248.0                            True
# 23452320119                       2000.0                            True
# 23452320119                       2000.0                            True
# 23452320119                       2000.0                            True

# %%
train_df = train_df.merge(user_answers_df, how='left', on='user_id')
train_df = train_df.merge(content_answers_df, how='left', on='content_id')

print(train_df.dtypes)
print(train_df.shape)
train_df.head()
# Out:
# user_id                             int32
# content_id                          int16
# answered_correctly                   int8
# prior_question_elapsed_time       float16
# prior_question_had_explanation    boolean
# mean_user_accuracy                float64
# questions_answered                float64
# std_user_accuracy                 float64
# median_user_accuracy              float64
# skew_user_accuracy                float64
# mean_accuracy                     float64
# question_asked                    float64
# std_accuracy                      float64
# median_accuracy                   float64
# skew_accuracy                     float64
# dtype: object
# (97953, 15)
#     user_id  content_id  answered_correctly  prior_question_elapsed_time  \
# 0  18789336        8144                   0                       4248.0
# 1  18789336        8146                   0                       4248.0
# 2  18789336       10166                   0                       2000.0
# 3  18789336       10165                   0                       2000.0
# 4  18789336       10167                   1                       2000.0
#
#    prior_question_had_explanation  mean_user_accuracy  questions_answered  \
# 0                            True            0.309689              2312.0
# 1                            True            0.309689              2312.0
# 2                            True            0.309689              2312.0
# 3                            True            0.309689              2312.0
# 4                            True            0.309689              2312.0
#
#    std_user_accuracy  median_user_accuracy  skew_user_accuracy  mean_accuracy  \
# 0           0.462465                   0.0            0.823743       0.454545
# 1           0.462465                   0.0            0.823743       0.696970
# 2           0.462465                   0.0            0.823743       0.916667
# 3           0.462465                   0.0            0.823743       0.416667
# 4           0.462465                   0.0            0.823743       0.770833
#
#    question_asked  std_accuracy  median_accuracy  skew_accuracy
# 0            33.0      0.505650              0.0       0.191386
# 1            33.0      0.466694              1.0      -0.898565
# 2            48.0      0.279310              1.0      -3.113260
# 3            48.0      0.498224              0.0       0.349066
# 4            48.0      0.424744              1.0      -1.330724

# %% [markdown]
# # Preprocess

# %%
train_df['prior_question_had_explanation'] = train_df['prior_question_had_explanation'].fillna(value=False).astype(bool)
train_df = train_df.fillna(value=0.5)

print(train_df.isnull().sum())
# Out:
# user_id                           0
# content_id                        0
# answered_correctly                0
# prior_question_elapsed_time       0
# prior_question_had_explanation    0
# mean_user_accuracy                0
# questions_answered                0
# std_user_accuracy                 0
# median_user_accuracy              0
# skew_user_accuracy                0
# mean_accuracy                     0
# question_asked                    0
# std_accuracy                      0
# median_accuracy                   0
# skew_accuracy                     0
# dtype: int64

# %%
train_df = train_df[features + [target]]
train_df = train_df.replace([np.inf, -np.inf], np.nan)
train_df = train_df.fillna(0.5)

print(train_df.isnull().sum())
# Out:
# mean_user_accuracy                0
# questions_answered                0
# std_user_accuracy                 0
# median_user_accuracy              0
# skew_user_accuracy                0
# mean_accuracy                     0
# question_asked                    0
# std_accuracy                      0
# median_accuracy                   0
# prior_question_elapsed_time       0
# prior_question_had_explanation    0
# skew_accuracy                     0
# answered_correctly                0
# dtype: int64

# %%
print(train_df.dtypes)
print(train_df.shape)
train_df.head()
# Out:
# mean_user_accuracy                float64
# questions_answered                float64
# std_user_accuracy                 float64
# median_user_accuracy              float64
# skew_user_accuracy                float64
# mean_accuracy                     float64
# question_asked                    float64
# std_accuracy                      float64
# median_accuracy                   float64
# prior_question_elapsed_time       float16
# prior_question_had_explanation       bool
# skew_accuracy                     float64
# answered_correctly                   int8
# dtype: object
# (97953, 13)
#    mean_user_accuracy  questions_answered  std_user_accuracy  \
# 0            0.309689              2312.0           0.462465
# 1            0.309689              2312.0           0.462465
# 2            0.309689              2312.0           0.462465
# 3            0.309689              2312.0           0.462465
# 4            0.309689              2312.0           0.462465
#
#    median_user_accuracy  skew_user_accuracy  mean_accuracy  question_asked  \
# 0                   0.0            0.823743       0.454545            33.0
# 1                   0.0            0.823743       0.696970            33.0
# 2                   0.0            0.823743       0.916667            48.0
# 3                   0.0            0.823743       0.416667            48.0
# 4                   0.0            0.823743       0.770833            48.0
#
#    std_accuracy  median_accuracy  prior_question_elapsed_time  \
# 0      0.505650              0.0                       4248.0
# 1      0.466694              1.0                       4248.0
# 2      0.279310              1.0                       2000.0
# 3      0.498224              0.0                       2000.0
# 4      0.424744              1.0                       2000.0
#
#    prior_question_had_explanation  skew_accuracy  answered_correctly
# 0                            True       0.191386                   0
# 1                            True      -0.898565                   0
# 2                            True      -3.113260                   0
# 3                            True       0.349066                   0
# 4                            True      -1.330724                   1

# %%
train_df, test_df = train_test_split(train_df, random_state=666, test_size=0.2)

print(train_df.shape)
print(test_df.shape)
train_df.head()
# Out:
# (78362, 13)
# (19591, 13)
#        mean_user_accuracy  questions_answered  std_user_accuracy  \
# 20721                 0.5                 0.5                0.5
# 488                   0.5                 0.5                0.5
# 54213                 0.5                 0.5                0.5
# 62049                 0.5                 0.5                0.5
# 51788                 0.5                 0.5                0.5
#
#        median_user_accuracy  skew_user_accuracy  mean_accuracy  \
# 20721                   0.5                 0.5       0.610860
# 488                     0.5                 0.5       0.573427
# 54213                   0.5                 0.5       0.622951
# 62049                   0.5                 0.5       0.711670
# 51788                   0.5                 0.5       0.761905
#
#        question_asked  std_accuracy  median_accuracy  \
# 20721           221.0      0.488662              1.0
# 488             429.0      0.495157              1.0
# 54213           183.0      0.485977              1.0
# 62049           437.0      0.453504              1.0
# 51788            42.0      0.431081              1.0
#
#        prior_question_elapsed_time  prior_question_had_explanation  \
# 20721                      25328.0                            True
# 488                        15000.0                            True
# 54213                      20000.0                            True
# 62049                      26000.0                            True
# 51788                      27008.0                            True
#
#        skew_accuracy  answered_correctly
# 20721      -0.457871                   1
# 488        -0.297968                   0
# 54213      -0.511585                   0
# 62049      -0.937780                   0
# 51788      -1.275864                   1

# %%
def create_model(trial):
    num_leaves = trial.suggest_int("num_leaves", 2, 31)
    n_estimators = trial.suggest_int("n_estimators", 50, 300)
    max_depth = trial.suggest_int('max_depth', 3, 8)
    min_child_samples = trial.suggest_int('min_child_samples', 100, 1200)
    learning_rate = trial.suggest_uniform('learning_rate', 0.0001, 0.99)
    min_data_in_leaf = trial.suggest_int('min_data_in_leaf', 5, 90)
    bagging_fraction = trial.suggest_uniform('bagging_fraction', 0.0001, 1.0)
    feature_fraction = trial.suggest_uniform('feature_fraction', 0.0001, 1.0)
    
    model = lgb.LGBMClassifier(
        num_leaves=num_leaves,
        n_estimators=n_estimators, 
        max_depth=max_depth, 
        min_child_samples=min_child_samples, 
        min_data_in_leaf=min_data_in_leaf,
        learning_rate=learning_rate,
        feature_fraction=feature_fraction,
        random_state=666
    )
    return model

# %% [markdown]
# # Modeling

# %%
def objective(trial):
    model = create_model(trial)
    model.fit(train_df[features], train_df[target])
    score = roc_auc_score(
        test_df[target].values, 
        model.predict_proba(test_df[features])[:,1]
    )
    return score

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=70)
params = study.best_params

print(params)
# Out:
# [I 2020-12-04 13:44:19,319] A new study created in memory with name: no-name-8e0516e2-733e-4656-9997-945819e6a950
# [I 2020-12-04 13:44:20,303] Trial 0 finished with value: 0.7137533757338496 and parameters: {'num_leaves': 10, 'n_estimators': 153, 'max_depth': 6, 'min_child_samples': 502, 'learning_rate': 0.00842866332617725, 'min_data_in_leaf': 42, 'bagging_fraction': 0.6722554903615628, 'feature_fraction': 0.6021600976634363}. Best is trial 0 with value: 0.7137533757338496.
# [I 2020-12-04 13:44:21,432] Trial 1 finished with value: 0.7128598114681889 and parameters: {'num_leaves': 23, 'n_estimators': 251, 'max_depth': 8, 'min_child_samples': 900, 'learning_rate': 0.11414539829830528, 'min_data_in_leaf': 25, 'bagging_fraction': 0.14831951703795024, 'feature_fraction': 0.18605210543009315}. Best is trial 0 with value: 0.7137533757338496.
# [I 2020-12-04 13:44:22,503] Trial 2 finished with value: 0.6989484425955388 and parameters: {'num_leaves': 23, 'n_estimators': 259, 'max_depth': 6, 'min_child_samples': 671, 'learning_rate': 0.6821915640905226, 'min_data_in_leaf': 74, 'bagging_fraction': 0.15006647674918488, 'feature_fraction': 0.010144616547623641}. Best is trial 0 with value: 0.7137533757338496.
# [I 2020-12-04 13:44:23,357] Trial 3 finished with value: 0.7129816258681547 and parameters: {'num_leaves': 28, 'n_estimators': 238, 'max_depth': 3, 'min_child_samples': 280, 'learning_rate': 0.328684841764646, 'min_data_in_leaf': 18, 'bagging_fraction': 0.6898663177777785, 'feature_fraction': 0.024216873102191866}. Best is trial 0 with value: 0.7137533757338496.
# [I 2020-12-04 13:44:24,194] Trial 4 finished with value: 0.713634855013158 and parameters: {'num_leaves': 2, 'n_estimators': 264, 'max_depth': 5, 'min_child_samples': 806, 'learning_rate': 0.07359660483766041, 'min_data_in_leaf': 66, 'bagging_fraction': 0.48412756177073407, 'feature_fraction': 0.0652782631053931}. Best is trial 0 with value: 0.7137533757338496.
# [I 2020-12-04 13:44:24,939] Trial 5 finished with value: 0.7100656218173315 and parameters: {'num_leaves': 23, 'n_estimators': 140, 'max_depth': 6, 'min_child_samples': 1030, 'learning_rate': 0.47922641947017786, 'min_data_in_leaf': 30, 'bagging_fraction': 0.37436575315949405, 'feature_fraction': 0.040036141462514184}. Best is trial 0 with value: 0.7137533757338496.
# [I 2020-12-04 13:44:26,017] Trial 6 finished with value: 0.6906867970825704 and parameters: {'num_leaves': 23, 'n_estimators': 192, 'max_depth': 7, 'min_child_samples': 1022, 'learning_rate': 0.88522739639692, 'min_data_in_leaf': 18, 'bagging_fraction': 0.04982687576281433, 'feature_fraction': 0.3645917887185944}. Best is trial 0 with value: 0.7137533757338496.
# [I 2020-12-04 13:44:28,087] Trial 7 finished with value: 0.7143608210125012 and parameters: {'num_leaves': 29, 'n_estimators': 297, 'max_depth': 7, 'min_child_samples': 483, 'learning_rate': 0.0008230081851018934, 'min_data_in_leaf': 37, 'bagging_fraction': 0.8860496553623752, 'feature_fraction': 0.9467614527742206}. Best is trial 7 with value: 0.7143608210125012.
# [I 2020-12-04 13:44:28,675] Trial 8 finished with value: 0.7149362377031663 and parameters: {'num_leaves': 6, 'n_estimators': 81, 'max_depth': 5, 'min_child_samples': 157, 'learning_rate': 0.15689396435896472, 'min_data_in_leaf': 20, 'bagging_fraction': 0.03718560222006341, 'feature_fraction': 0.9092626553298333}. Best is trial 8 with value: 0.7149362377031663.
# [I 2020-12-04 13:44:29,776] Trial 9 finished with value: 0.6910393414756764 and parameters: {'num_leaves': 28, 'n_estimators': 222, 'max_depth': 6, 'min_child_samples': 277, 'learning_rate': 0.8064095451669201, 'min_data_in_leaf': 46, 'bagging_fraction': 0.1938161867898099, 'feature_fraction': 0.45718405568797044}. Best is trial 8 with value: 0.7149362377031663.
# [I 2020-12-04 13:44:30,254] Trial 10 finished with value: 0.7133311697366862 and parameters: {'num_leaves': 2, 'n_estimators': 56, 'max_depth': 4, 'min_child_samples': 119, 'learning_rate': 0.282432978437828, 'min_data_in_leaf': 10, 'bagging_fraction': 0.3706685073373319, 'feature_fraction': 0.9900450948911047}. Best is trial 8 with value: 0.7149362377031663.
# [I 2020-12-04 13:44:30,772] Trial 11 finished with value: 0.7145342823728148 and parameters: {'num_leaves': 10, 'n_estimators': 51, 'max_depth': 8, 'min_child_samples': 453, 'learning_rate': 0.2141945605737426, 'min_data_in_leaf': 35, 'bagging_fraction': 0.9959549459225545, 'feature_fraction': 0.9866631054108932}. Best is trial 8 with value: 0.7149362377031663.
# [I 2020-12-04 13:44:31,291] Trial 12 finished with value: 0.7148827973258314 and parameters: {'num_leaves': 9, 'n_estimators': 51, 'max_depth': 4, 'min_child_samples': 105, 'learning_rate': 0.24246447572179555, 'min_data_in_leaf': 57, 'bagging_fraction': 0.9194348931864238, 'feature_fraction': 0.8048787396667474}. Best is trial 8 with value: 0.7149362377031663.
# [I 2020-12-04 13:44:31,917] Trial 13 finished with value: 0.7123658975322007 and parameters: {'num_leaves': 8, 'n_estimators': 95, 'max_depth': 4, 'min_child_samples': 159, 'learning_rate': 0.45558935597842126, 'min_data_in_leaf': 56, 'bagging_fraction': 0.7817693373329933, 'feature_fraction': 0.772546508137389}. Best is trial 8 with value: 0.7149362377031663.
# [I 2020-12-04 13:44:32,602] Trial 14 finished with value: 0.7142864746813782 and parameters: {'num_leaves': 14, 'n_estimators': 94, 'max_depth': 4, 'min_child_samples': 107, 'learning_rate': 0.20110415527897352, 'min_data_in_leaf': 58, 'bagging_fraction': 0.9558443891367785, 'feature_fraction': 0.7937041471301834}. Best is trial 8 with value: 0.7149362377031663.
# [I 2020-12-04 13:44:33,184] Trial 15 finished with value: 0.7138950844164824 and parameters: {'num_leaves': 6, 'n_estimators': 90, 'max_depth': 3, 'min_child_samples': 300, 'learning_rate': 0.3712064203674036, 'min_data_in_leaf': 86, 'bagging_fraction': 0.006186047661748073, 'feature_fraction': 0.8179998201115908}. Best is trial 8 with value: 0.7149362377031663.
# [I 2020-12-04 13:44:33,688] Trial 16 finished with value: 0.709878801799717 and parameters: {'num_leaves': 15, 'n_estimators': 52, 'max_depth': 5, 'min_child_samples': 1177, 'learning_rate': 0.5903098069153669, 'min_data_in_leaf': 6, 'bagging_fraction': 0.5938935184092431, 'feature_fraction': 0.6471864483913509}. Best is trial 8 with value: 0.7149362377031663.
# [I 2020-12-04 13:44:34,357] Trial 17 finished with value: 0.7148447791849587 and parameters: {'num_leaves': 5, 'n_estimators': 126, 'max_depth': 5, 'min_child_samples': 192, 'learning_rate': 0.15279233296940997, 'min_data_in_leaf': 83, 'bagging_fraction': 0.30379369088657043, 'feature_fraction': 0.8961221663441241}. Best is trial 8 with value: 0.7149362377031663.
# [I 2020-12-04 13:44:34,926] Trial 18 finished with value: 0.7121727775626061 and parameters: {'num_leaves': 12, 'n_estimators': 75, 'max_depth': 4, 'min_child_samples': 397, 'learning_rate': 0.40916068133001426, 'min_data_in_leaf': 52, 'bagging_fraction': 0.8319565921659718, 'feature_fraction': 0.6705358261931802}. Best is trial 8 with value: 0.7149362377031663.
# [I 2020-12-04 13:44:35,996] Trial 19 finished with value: 0.7146003111578472 and parameters: {'num_leaves': 5, 'n_estimators': 118, 'max_depth': 3, 'min_child_samples': 634, 'learning_rate': 0.27508662140972207, 'min_data_in_leaf': 66, 'bagging_fraction': 0.5227486126807328, 'feature_fraction': 0.8694232695574167}. Best is trial 8 with value: 0.7149362377031663.
# [I 2020-12-04 13:44:36,836] Trial 20 finished with value: 0.7146287988969107 and parameters: {'num_leaves': 2, 'n_estimators': 178, 'max_depth': 5, 'min_child_samples': 100, 'learning_rate': 0.5476626029581204, 'min_data_in_leaf': 74, 'bagging_fraction': 0.2687168378981103, 'feature_fraction': 0.7372809857519426}. Best is trial 8 with value: 0.7149362377031663.
# [I 2020-12-04 13:44:37,552] Trial 21 finished with value: 0.7151150390775215 and parameters: {'num_leaves': 6, 'n_estimators': 123, 'max_depth': 5, 'min_child_samples': 208, 'learning_rate': 0.1041582918529789, 'min_data_in_leaf': 89, 'bagging_fraction': 0.3219959980290825, 'feature_fraction': 0.899263919258129}. Best is trial 21 with value: 0.7151150390775215.
# [I 2020-12-04 13:44:38,180] Trial 22 finished with value: 0.7152542415748777 and parameters: {'num_leaves': 19, 'n_estimators': 71, 'max_depth': 4, 'min_child_samples': 200, 'learning_rate': 0.05178724135245977, 'min_data_in_leaf': 90, 'bagging_fraction': 0.04372795626379972, 'feature_fraction': 0.9013027444498809}. Best is trial 22 with value: 0.7152542415748777.
# [I 2020-12-04 13:44:38,998] Trial 23 finished with value: 0.7156386306157663 and parameters: {'num_leaves': 19, 'n_estimators': 110, 'max_depth': 5, 'min_child_samples': 354, 'learning_rate': 0.04830448794267172, 'min_data_in_leaf': 90, 'bagging_fraction': 0.06186590600023398, 'feature_fraction': 0.915028553241014}. Best is trial 23 with value: 0.7156386306157663.
# [I 2020-12-04 13:44:39,851] Trial 24 finished with value: 0.7131348135691309 and parameters: {'num_leaves': 19, 'n_estimators': 114, 'max_depth': 4, 'min_child_samples': 373, 'learning_rate': 0.004633896371801061, 'min_data_in_leaf': 90, 'bagging_fraction': 0.07578151589084575, 'feature_fraction': 0.9986725958571203}. Best is trial 23 with value: 0.7156386306157663.
# [I 2020-12-04 13:44:40,728] Trial 25 finished with value: 0.7152403425932281 and parameters: {'num_leaves': 19, 'n_estimators': 156, 'max_depth': 5, 'min_child_samples': 269, 'learning_rate': 0.053992978716003615, 'min_data_in_leaf': 81, 'bagging_fraction': 0.23223551194109135, 'feature_fraction': 0.545227819170863}. Best is trial 23 with value: 0.7156386306157663.
# [I 2020-12-04 13:44:41,554] Trial 26 finished with value: 0.7152706180011471 and parameters: {'num_leaves': 19, 'n_estimators': 154, 'max_depth': 7, 'min_child_samples': 339, 'learning_rate': 0.05255552684446817, 'min_data_in_leaf': 80, 'bagging_fraction': 0.2138905378423487, 'feature_fraction': 0.31057274149591907}. Best is trial 23 with value: 0.7156386306157663.
# [I 2020-12-04 13:44:42,607] Trial 27 finished with value: 0.714851705683258 and parameters: {'num_leaves': 19, 'n_estimators': 203, 'max_depth': 7, 'min_child_samples': 606, 'learning_rate': 0.014426084898764964, 'min_data_in_leaf': 76, 'bagging_fraction': 0.1044640841915141, 'feature_fraction': 0.3460512430067456}. Best is trial 23 with value: 0.7156386306157663.
# [I 2020-12-04 13:44:43,414] Trial 28 finished with value: 0.7130758779782076 and parameters: {'num_leaves': 21, 'n_estimators': 159, 'max_depth': 7, 'min_child_samples': 375, 'learning_rate': 0.17066030300567137, 'min_data_in_leaf': 90, 'bagging_fraction': 0.015153868363182142, 'feature_fraction': 0.22369033703341556}. Best is trial 23 with value: 0.7156386306157663.
# [I 2020-12-04 13:44:44,235] Trial 29 finished with value: 0.713043366547186 and parameters: {'num_leaves': 17, 'n_estimators': 137, 'max_depth': 6, 'min_child_samples': 570, 'learning_rate': 0.00024949317601688503, 'min_data_in_leaf': 79, 'bagging_fraction': 0.14550685769577237, 'feature_fraction': 0.2597792145280042}. Best is trial 23 with value: 0.7156386306157663.
# [I 2020-12-04 13:44:44,861] Trial 30 finished with value: 0.7154492641759554 and parameters: {'num_leaves': 26, 'n_estimators': 71, 'max_depth': 8, 'min_child_samples': 525, 'learning_rate': 0.06759019925384317, 'min_data_in_leaf': 68, 'bagging_fraction': 0.0006848722851331215, 'feature_fraction': 0.4650768756109798}. Best is trial 23 with value: 0.7156386306157663.
# [I 2020-12-04 13:44:45,496] Trial 31 finished with value: 0.7153231559218571 and parameters: {'num_leaves': 26, 'n_estimators': 71, 'max_depth': 8, 'min_child_samples': 539, 'learning_rate': 0.049093210878901686, 'min_data_in_leaf': 69, 'bagging_fraction': 0.005186124272894575, 'feature_fraction': 0.44053498041676376}. Best is trial 23 with value: 0.7156386306157663.
# [I 2020-12-04 13:44:46,218] Trial 32 finished with value: 0.7145121923039649 and parameters: {'num_leaves': 31, 'n_estimators': 102, 'max_depth': 8, 'min_child_samples': 537, 'learning_rate': 0.11068179397057507, 'min_data_in_leaf': 65, 'bagging_fraction': 0.12880724268265817, 'feature_fraction': 0.4584474593460722}. Best is trial 23 with value: 0.7156386306157663.
# [I 2020-12-04 13:44:46,818] Trial 33 finished with value: 0.7152275587490641 and parameters: {'num_leaves': 26, 'n_estimators': 71, 'max_depth': 8, 'min_child_samples': 719, 'learning_rate': 0.07831354439312938, 'min_data_in_leaf': 67, 'bagging_fraction': 0.001154052281206918, 'feature_fraction': 0.3484901459280306}. Best is trial 23 with value: 0.7156386306157663.
# [I 2020-12-04 13:44:47,697] Trial 34 finished with value: 0.7143205898410514 and parameters: {'num_leaves': 25, 'n_estimators': 108, 'max_depth': 8, 'min_child_samples': 443, 'learning_rate': 0.0028448870027085876, 'min_data_in_leaf': 71, 'bagging_fraction': 0.20056589720147563, 'feature_fraction': 0.576120151833837}. Best is trial 23 with value: 0.7156386306157663.
# [I 2020-12-04 13:44:48,667] Trial 35 finished with value: 0.7126551320064117 and parameters: {'num_leaves': 25, 'n_estimators': 175, 'max_depth': 7, 'min_child_samples': 703, 'learning_rate': 0.13796465322231694, 'min_data_in_leaf': 62, 'bagging_fraction': 0.10429991944867412, 'feature_fraction': 0.4168769833364024}. Best is trial 23 with value: 0.7156386306157663.
# [I 2020-12-04 13:44:49,414] Trial 36 finished with value: 0.710967101259887 and parameters: {'num_leaves': 21, 'n_estimators': 140, 'max_depth': 8, 'min_child_samples': 532, 'learning_rate': 0.29957557237133503, 'min_data_in_leaf': 71, 'bagging_fraction': 0.19711647693310644, 'feature_fraction': 0.28154416835871454}. Best is trial 23 with value: 0.7156386306157663.
# [I 2020-12-04 13:44:49,977] Trial 37 finished with value: 0.7150325476442491 and parameters: {'num_leaves': 21, 'n_estimators': 62, 'max_depth': 7, 'min_child_samples': 353, 'learning_rate': 0.05952532156647891, 'min_data_in_leaf': 83, 'bagging_fraction': 0.0028133933447829773, 'feature_fraction': 0.15081019390955724}. Best is trial 23 with value: 0.7156386306157663.
# [I 2020-12-04 13:44:50,617] Trial 38 finished with value: 0.7115754317507694 and parameters: {'num_leaves': 31, 'n_estimators': 87, 'max_depth': 8, 'min_child_samples': 824, 'learning_rate': 0.19931528657343878, 'min_data_in_leaf': 77, 'bagging_fraction': 0.4480656193462278, 'feature_fraction': 0.4989217301175837}. Best is trial 23 with value: 0.7156386306157663.
# [I 2020-12-04 13:44:51,452] Trial 39 finished with value: 0.7134777930716393 and parameters: {'num_leaves': 26, 'n_estimators': 159, 'max_depth': 6, 'min_child_samples': 478, 'learning_rate': 0.11837573029132267, 'min_data_in_leaf': 70, 'bagging_fraction': 0.09255378357955046, 'feature_fraction': 0.11863844442145671}. Best is trial 23 with value: 0.7156386306157663.
# [I 2020-12-04 13:44:52,208] Trial 40 finished with value: 0.7108705211566297 and parameters: {'num_leaves': 17, 'n_estimators': 135, 'max_depth': 7, 'min_child_samples': 320, 'learning_rate': 0.35379805725011365, 'min_data_in_leaf': 61, 'bagging_fraction': 0.18555876406759053, 'feature_fraction': 0.3907836728111477}. Best is trial 23 with value: 0.7156386306157663.
# [I 2020-12-04 13:44:52,809] Trial 41 finished with value: 0.7148741463881214 and parameters: {'num_leaves': 23, 'n_estimators': 67, 'max_depth': 8, 'min_child_samples': 425, 'learning_rate': 0.04578922088046069, 'min_data_in_leaf': 86, 'bagging_fraction': 0.07187286742742056, 'feature_fraction': 0.30817077853114866}. Best is trial 23 with value: 0.7156386306157663.
# [I 2020-12-04 13:44:53,433] Trial 42 finished with value: 0.7150862236949701 and parameters: {'num_leaves': 15, 'n_estimators': 78, 'max_depth': 6, 'min_child_samples': 258, 'learning_rate': 0.03276469403710312, 'min_data_in_leaf': 85, 'bagging_fraction': 0.04860638504967361, 'feature_fraction': 0.4461187338837612}. Best is trial 23 with value: 0.7156386306157663.
# [I 2020-12-04 13:44:54,056] Trial 43 finished with value: 0.7155940481088705 and parameters: {'num_leaves': 29, 'n_estimators': 106, 'max_depth': 3, 'min_child_samples': 225, 'learning_rate': 0.0840181158501221, 'min_data_in_leaf': 79, 'bagging_fraction': 0.0022164421637588796, 'feature_fraction': 0.5071174298887128}. Best is trial 23 with value: 0.7156386306157663.
# [I 2020-12-04 13:44:54,777] Trial 44 finished with value: 0.6874982798716879 and parameters: {'num_leaves': 29, 'n_estimators': 107, 'max_depth': 7, 'min_child_samples': 508, 'learning_rate': 0.98954966150147, 'min_data_in_leaf': 73, 'bagging_fraction': 0.149717053381501, 'feature_fraction': 0.6358156036589875}. Best is trial 23 with value: 0.7156386306157663.
# [I 2020-12-04 13:44:55,511] Trial 45 finished with value: 0.7152181777986704 and parameters: {'num_leaves': 28, 'n_estimators': 103, 'max_depth': 8, 'min_child_samples': 608, 'learning_rate': 0.0791169696910059, 'min_data_in_leaf': 79, 'bagging_fraction': 0.2598771111956216, 'feature_fraction': 0.5356106252692632}. Best is trial 23 with value: 0.7156386306157663.
# [I 2020-12-04 13:44:56,168] Trial 46 finished with value: 0.7126581440272488 and parameters: {'num_leaves': 30, 'n_estimators': 83, 'max_depth': 8, 'min_child_samples': 314, 'learning_rate': 0.2330189994740492, 'min_data_in_leaf': 43, 'bagging_fraction': 0.01010673502753819, 'feature_fraction': 0.4863489756138211}. Best is trial 23 with value: 0.7156386306157663.
# [I 2020-12-04 13:44:56,960] Trial 47 finished with value: 0.7124180503281092 and parameters: {'num_leaves': 27, 'n_estimators': 149, 'max_depth': 7, 'min_child_samples': 419, 'learning_rate': 0.1735289595469563, 'min_data_in_leaf': 49, 'bagging_fraction': 0.06334982892128194, 'feature_fraction': 0.19991886698548894}. Best is trial 23 with value: 0.7156386306157663.
# [I 2020-12-04 13:44:57,772] Trial 48 finished with value: 0.7151336917638129 and parameters: {'num_leaves': 23, 'n_estimators': 192, 'max_depth': 3, 'min_child_samples': 756, 'learning_rate': 0.11129042143791618, 'min_data_in_leaf': 76, 'bagging_fraction': 0.12294600193743156, 'feature_fraction': 0.3993455869503606}. Best is trial 23 with value: 0.7156386306157663.
# [I 2020-12-04 13:44:58,501] Trial 49 finished with value: 0.7027797043598083 and parameters: {'num_leaves': 24, 'n_estimators': 127, 'max_depth': 7, 'min_child_samples': 565, 'learning_rate': 0.7726148582965153, 'min_data_in_leaf': 69, 'bagging_fraction': 0.4118594569560192, 'feature_fraction': 0.31768995772309183}. Best is trial 23 with value: 0.7156386306157663.
# [I 2020-12-04 13:44:59,754] Trial 50 finished with value: 0.7050055590178467 and parameters: {'num_leaves': 21, 'n_estimators': 297, 'max_depth': 8, 'min_child_samples': 240, 'learning_rate': 0.2546468630486313, 'min_data_in_leaf': 62, 'bagging_fraction': 0.008845840040954121, 'feature_fraction': 0.5404552755535141}. Best is trial 23 with value: 0.7156386306157663.
# [I 2020-12-04 13:45:00,441] Trial 51 finished with value: 0.7156820749926509 and parameters: {'num_leaves': 18, 'n_estimators': 93, 'max_depth': 4, 'min_child_samples': 170, 'learning_rate': 0.07741649235014227, 'min_data_in_leaf': 87, 'bagging_fraction': 0.04298795316642745, 'feature_fraction': 0.9588924282311444}. Best is trial 51 with value: 0.7156820749926509.
# [I 2020-12-04 13:45:01,071] Trial 52 finished with value: 0.7153150797972841 and parameters: {'num_leaves': 13, 'n_estimators': 97, 'max_depth': 3, 'min_child_samples': 153, 'learning_rate': 0.08417150675193977, 'min_data_in_leaf': 87, 'bagging_fraction': 0.03889832461307845, 'feature_fraction': 0.9563144240443627}. Best is trial 51 with value: 0.7156820749926509.
# [I 2020-12-04 13:45:01,682] Trial 53 finished with value: 0.7147066688325625 and parameters: {'num_leaves': 12, 'n_estimators': 93, 'max_depth': 3, 'min_child_samples': 161, 'learning_rate': 0.1499942993739457, 'min_data_in_leaf': 87, 'bagging_fraction': 0.042388624252615824, 'feature_fraction': 0.952317013946453}. Best is trial 51 with value: 0.7156820749926509.
# [I 2020-12-04 13:45:02,211] Trial 54 finished with value: 0.7151960589891635 and parameters: {'num_leaves': 13, 'n_estimators': 60, 'max_depth': 3, 'min_child_samples': 152, 'learning_rate': 0.0940500616491269, 'min_data_in_leaf': 83, 'bagging_fraction': 0.16923356460061248, 'feature_fraction': 0.9556359532560459}. Best is trial 51 with value: 0.7156820749926509.
# [I 2020-12-04 13:45:02,720] Trial 55 finished with value: 0.7150854764378921 and parameters: {'num_leaves': 16, 'n_estimators': 50, 'max_depth': 3, 'min_child_samples': 228, 'learning_rate': 0.17633011563645973, 'min_data_in_leaf': 87, 'bagging_fraction': 0.0021179010508530615, 'feature_fraction': 0.8577912229948765}. Best is trial 51 with value: 0.7156820749926509.
# [I 2020-12-04 13:45:03,437] Trial 56 finished with value: 0.7142232797251106 and parameters: {'num_leaves': 10, 'n_estimators': 100, 'max_depth': 4, 'min_child_samples': 136, 'learning_rate': 0.021051581989954556, 'min_data_in_leaf': 75, 'bagging_fraction': 0.6817963489992638, 'feature_fraction': 0.6901277246321591}. Best is trial 51 with value: 0.7156820749926509.
# [I 2020-12-04 13:45:04,050] Trial 57 finished with value: 0.7144946087701081 and parameters: {'num_leaves': 29, 'n_estimators': 86, 'max_depth': 4, 'min_child_samples': 284, 'learning_rate': 0.21035325902727764, 'min_data_in_leaf': 83, 'bagging_fraction': 0.08390192285621265, 'feature_fraction': 0.7350794783605707}. Best is trial 51 with value: 0.7156820749926509.
# [I 2020-12-04 13:45:04,683] Trial 58 finished with value: 0.7152974905152958 and parameters: {'num_leaves': 11, 'n_estimators': 114, 'max_depth': 3, 'min_child_samples': 657, 'learning_rate': 0.13756463940196276, 'min_data_in_leaf': 90, 'bagging_fraction': 0.028898368854755867, 'feature_fraction': 0.5928724024798764}. Best is trial 51 with value: 0.7156820749926509.
# [I 2020-12-04 13:45:05,396] Trial 59 finished with value: 0.7130375436901096 and parameters: {'num_leaves': 14, 'n_estimators': 81, 'max_depth': 4, 'min_child_samples': 185, 'learning_rate': 0.00157201894628025, 'min_data_in_leaf': 52, 'bagging_fraction': 0.11899339383150867, 'feature_fraction': 0.8398542831109245}. Best is trial 51 with value: 0.7156820749926509.
# [I 2020-12-04 13:45:06,500] Trial 60 finished with value: 0.7148274658132759 and parameters: {'num_leaves': 18, 'n_estimators': 270, 'max_depth': 3, 'min_child_samples': 473, 'learning_rate': 0.08020749570587134, 'min_data_in_leaf': 79, 'bagging_fraction': 0.058699453657452695, 'feature_fraction': 0.9977955842834356}. Best is trial 51 with value: 0.7156820749926509.
# [I 2020-12-04 13:45:07,146] Trial 61 finished with value: 0.71521120531532 and parameters: {'num_leaves': 11, 'n_estimators': 114, 'max_depth': 3, 'min_child_samples': 755, 'learning_rate': 0.13096622755446607, 'min_data_in_leaf': 90, 'bagging_fraction': 0.030959470227074327, 'feature_fraction': 0.5698532080992692}. Best is trial 51 with value: 0.7156820749926509.
# [I 2020-12-04 13:45:08,282] Trial 62 finished with value: 0.71415898112762 and parameters: {'num_leaves': 8, 'n_estimators': 96, 'max_depth': 3, 'min_child_samples': 652, 'learning_rate': 0.03187922594364317, 'min_data_in_leaf': 85, 'bagging_fraction': 0.0408363848459824, 'feature_fraction': 0.4493580001840598}. Best is trial 51 with value: 0.7156820749926509.
# [I 2020-12-04 13:45:08,939] Trial 63 finished with value: 0.7153906907173082 and parameters: {'num_leaves': 13, 'n_estimators': 122, 'max_depth': 3, 'min_child_samples': 605, 'learning_rate': 0.09950913617248058, 'min_data_in_leaf': 88, 'bagging_fraction': 0.1539244690500419, 'feature_fraction': 0.5967611604751155}. Best is trial 51 with value: 0.7156820749926509.
# [I 2020-12-04 13:45:09,830] Trial 64 finished with value: 0.715034588230885 and parameters: {'num_leaves': 15, 'n_estimators': 125, 'max_depth': 4, 'min_child_samples': 619, 'learning_rate': 0.10255205052940677, 'min_data_in_leaf': 81, 'bagging_fraction': 0.154410492593518, 'feature_fraction': 0.9290358704390537}. Best is trial 51 with value: 0.7156820749926509.
# [I 2020-12-04 13:45:10,408] Trial 65 finished with value: 0.7144672879017124 and parameters: {'num_leaves': 14, 'n_estimators': 66, 'max_depth': 5, 'min_child_samples': 515, 'learning_rate': 0.1879468134895954, 'min_data_in_leaf': 88, 'bagging_fraction': 0.6150037020652318, 'feature_fraction': 0.5103142066601787}. Best is trial 51 with value: 0.7156820749926509.
# [I 2020-12-04 13:45:10,974] Trial 66 finished with value: 0.7152594206412408 and parameters: {'num_leaves': 27, 'n_estimators': 77, 'max_depth': 3, 'min_child_samples': 568, 'learning_rate': 0.06431295048655856, 'min_data_in_leaf': 83, 'bagging_fraction': 0.0827180941693841, 'feature_fraction': 0.637596404474326}. Best is trial 51 with value: 0.7156820749926509.
# [I 2020-12-04 13:45:11,631] Trial 67 finished with value: 0.7129564720452852 and parameters: {'num_leaves': 16, 'n_estimators': 92, 'max_depth': 4, 'min_child_samples': 106, 'learning_rate': 0.0010763120642697174, 'min_data_in_leaf': 73, 'bagging_fraction': 0.7321691553882064, 'feature_fraction': 0.42566640328186084}. Best is trial 51 with value: 0.7156820749926509.
# [I 2020-12-04 13:45:12,325] Trial 68 finished with value: 0.7156104992608477 and parameters: {'num_leaves': 13, 'n_estimators': 109, 'max_depth': 5, 'min_child_samples': 691, 'learning_rate': 0.086748695664977, 'min_data_in_leaf': 25, 'bagging_fraction': 0.0004893555173453024, 'feature_fraction': 0.37132913135718937}. Best is trial 51 with value: 0.7156820749926509.
# [I 2020-12-04 13:45:13,006] Trial 69 finished with value: 0.7057216094905788 and parameters: {'num_leaves': 30, 'n_estimators': 108, 'max_depth': 5, 'min_child_samples': 879, 'learning_rate': 0.6613586422987193, 'min_data_in_leaf': 13, 'bagging_fraction': 0.10703972910450298, 'feature_fraction': 0.3588427331930688}. Best is trial 51 with value: 0.7156820749926509.
# {'num_leaves': 18, 'n_estimators': 93, 'max_depth': 4, 'min_child_samples': 170, 'learning_rate': 0.07741649235014227, 'min_data_in_leaf': 87, 'bagging_fraction': 0.04298795316642745, 'feature_fraction': 0.9588924282311444}

# %%
model = lgb.LGBMClassifier(**params)

model.fit(train_df[features], train_df[target])
print('LGB score: ', roc_auc_score(test_df[target].values, model.predict_proba(test_df[features])[:,1]))
# Out:
# LGB score:  0.7156820749926509

# %% [markdown]
# # Submit

# %%
for (test_df, sample_prediction_df) in iter_test:
    test_df = test_df.merge(user_answers_df, how='left', on='user_id')
    test_df = test_df.merge(content_answers_df, how='left', on='content_id')
    test_df['prior_question_had_explanation'] = test_df['prior_question_had_explanation'].fillna(value=False).astype(bool)
    test_df.fillna(value = 0.5, inplace = True)

    test_df['answered_correctly'] = model.predict_proba(test_df[features])[:,1]
    env.predict(test_df.loc[test_df['content_type_id'] == 0, ['row_id', 'answered_correctly']])
